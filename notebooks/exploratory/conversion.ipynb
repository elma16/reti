# %% [markdown]
# # How well are fundamental endings converted depending on ending and rating bracket?

# %% [markdown]
# ## Step 1 : Apply a collection of cql files to extract the relevant endings

# %%
import subprocess
import os
import chess
import chess.pgn

cql_bin_dir = '/Users/elliottmacneil/chess/cql6/cql'
cql_scripts_dir = '/Users/elliottmacneil/python/reti/src/100endings'
output_dir = '/Users/elliottmacneil/python/reti/output/'
iterated = False
db_dir = '/Users/elliottmacneil/chess/pgn/lichess/lichess_BurntBread_2022-04-07.pgn'

def run_cql_scripts(cql_scripts_dir, db, count, matchlow=1):
	if os.path.isdir(cql_scripts_dir):
		for file in os.listdir(cql_scripts_dir):
			file_dir = '{}/{}'.format(cql_scripts_dir,file)
			file_noext = os.path.splitext(file)[0]
			dir_noext = os.path.join(output_dir,file_noext)
			pgn_file = dir_noext+str(count)+'.pgn'
			cql_command = '{} -i {} -o {} -matchcount {} 100 -threads 20 {}'.format(cql_bin_dir, db, pgn_file, matchlow, file_dir)
			try:
				subprocess.run(cql_command,shell=True)
			except:
				print('failed')
			count += 1
		print('Done.')
	else:
		file_noext = cql_scripts_dir.split('/')[-1][:-4]
		pgn_file = file_noext+str(count)+'.pgn'
		cql_command = '{} -i {} -o {} -matchcount {} 100 -threads 20 {}'.format(cql_bin_dir, db, pgn_file, matchlow, cql_scripts_dir)
		try:
			subprocess.run(cql_command,shell=True)
		except:
			print('failed')
		print('Done.')

# %%
# run each script in cql_scripts_dir on each pgn in db_dir
if iterated:
    count = 0
    for filename in os.listdir(db_dir):
        if filename.endswith('.pgn'):
            print(filename)
            db = db_dir + '/' + filename 
            run_cql_scripts(cql_scripts_dir,db,count)
            count += 1
else:
    run_cql_scripts(cql_scripts_dir,db_dir,count=1)
# Out:
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 0 matches of 3231 games in 0.493 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/99Qrp1.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 5 matches of 3231 games in 0.444 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/77KPP2.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 7 matches of 3231 games in 0.414 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/11Np3.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 54 matches of 3231 games in 0.5 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/52_68RPr4.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 5 matches of 3231 games in 0.421 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/98RPb5.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 46 matches of 3231 games in 0.424 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/69_76RPPr6.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 75 matches of 3231 games in 0.417 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/13_15Np7.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 22 matches of 3231 games in 0.424 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/21_29Rvsp8.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 1 matches of 3231 games in 0.435 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/41ocBPPb9.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 66 matches of 3231 games in 0.415 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/1_5KP10.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 1 matches of 3231 games in 0.417 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/94_96RBr11.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 4 matches of 3231 games in 0.414 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/8_9Rn12.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 10 matches of 3231 games in 0.423 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/16_20Qp13.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 4 matches of 3231 games in 0.417 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/12Np14.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 14 matches of 3231 games in 0.416 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/55RPr15.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 3 matches of 3231 games in 0.413 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/10Np16.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 6 matches of 3231 games in 0.431 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/30_32Rvspp17.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 3 matches of 3231 games in 0.407 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/93BN18.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 4 matches of 3231 games in 0.403 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/97RPb19.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 19 matches of 3231 games in 0.412 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/78KPP20.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 41 matches of 3231 games in 0.397 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/79_82KPp21.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 5 matches of 3231 games in 0.403 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/57_58RPr22.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 2 matches of 3231 games in 0.409 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/100Qrp23.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 66 matches of 3231 games in 0.406 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/83_87KPPp24.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 2 matches of 3231 games in 0.436 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/33_36BPb25.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 13 matches of 3231 games in 0.405 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/56RPr26.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 2 matches of 3231 games in 0.415 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/42_43ocBPPb27.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 2 matches of 3231 games in 0.432 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/44_51ocBPPb28.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 5 matches of 3231 games in 0.41 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/6_7RB29.pgn
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# ...
# 8 matches of 3231 games in 0.428 seconds using 20 threads to /Users/elliottmacneil/python/reti/output/37_40BNP30.pgn
# Done.

# %% [markdown]
# ## Step 2 : Extract the first (for simplicity) ending of each game in the pgn, check valuation on tablebase, and append result, theoretical result and ratings to csv

# %%
import requests 
import pandas
import chess
import chess.pgn
from reti import utilities
import time
import matplotlib.pyplot as plt
import numpy as np

def check_tablebase(fen):
    r = requests.get('http://tablebase.lichess.ovh/standard?fen={}'.format(fen))
    return r.json()['category']

def compute_conversion(result1,result2):
    'result1 is the result from the tablebase, result2 is the result from the pgn'
    if result1 == result2:
        return 0
    elif result1 == '1-0' and result2 == '0-1':
        return -1
    elif result1 == '0-1' and result2 == '1-0':
        return 1
    elif result1 == '1/2-1/2' and result2 == '1-0':
        return 0.5
    elif result1 == '1/2-1/2' and result2 == '0-1':
        return -0.5
    elif result1 == '1-0' and result2 == '1/2-1/2':
        return -0.5
    elif result1 == '0-1' and result2 == '1/2-1/2':
        return 0.5

# %%
def pgn_to_data(path):
    '''
    TODO refactor the name, this sucks.
    '''
    fen_list = []
    side_to_move = []
    theoretical_result = []
    white_elo = []
    black_elo = []
    result = []
    white = []
    black = []
    conversion = []
    count = 0
    pgn = open(path, encoding='utf-8', errors='replace')

    with open(path, encoding="utf-8",errors='replace') as file:
        content = file.read()
    num_games = utilities.game_length_array(content)[0]
    print('number of games:',num_games)
    for _ in range(num_games):
        try:
            game = chess.pgn.read_game(pgn)
            board = game.board()
            for node in game.mainline():
                move = node.move
                comment = node.comment 
                board.push(move)
                if comment == 'CQL':
                    fen = board.fen()
                    fen_list.append(fen)
                    # work out what the result should be 
                    side_to_move = fen.split(' ')[1]
                    tablebase_eval = check_tablebase(fen)
                    if tablebase_eval == 'draw':
                        tablebase_eval = '1/2-1/2'
                    elif tablebase_eval == 'win' and side_to_move == 'w':
                        tablebase_eval = '1-0'
                    elif tablebase_eval == 'win' and side_to_move == 'b':
                        tablebase_eval = '0-1'
                    elif tablebase_eval == 'loss' and side_to_move == 'w':
                        tablebase_eval = '0-1'
                    elif tablebase_eval == 'loss' and side_to_move == 'b':
                        tablebase_eval = '1-0'
                    theoretical_result.append(tablebase_eval)
                    count += 1
                    try:
                        white_elo.append(float(game.headers['WhiteElo']))
                    except:
                        white_elo.append(0)
                    try:
                        black_elo.append(float(game.headers['BlackElo']))
                    except:
                        black_elo.append(0)
                    white.append(game.headers['White'])
                    black.append(game.headers['Black'])
                    result.append(game.headers['Result'])
                    conversion.append(compute_conversion(tablebase_eval,game.headers['Result']))
                    break
                # avoiding the rate limit on the api
                if count > 15:
                    count = 0 
                    time.sleep(60)
        except:
            pass
        else:
            continue
    return fen_list, white_elo, black_elo, white, black, theoretical_result, result, conversion

# %%
output_path = '/Users/elliottmacneil/python/reti/output/conversions/'
csv_path = '/Users/elliottmacneil/python/reti/output/csv/'
for file in os.listdir(output_path):
    if file.endswith('.pgn'):
        game = output_path+file
        print(game)
        fen_list, white_elo, black_elo, white, black, theoretical_result, result, conversion = pgn_to_data(game)
        df = pandas.DataFrame({'fen':fen_list, 'white_elo':white_elo, 'black_elo':black_elo, 'white':white, 'black':black, 'theoretical_result':theoretical_result, 'result':result,'conversion':conversion})
        df.to_csv(csv_path+file[:-4]+'.csv')
# Out:
# /Users/elliottmacneil/python/reti/output/conversions/77KPP2.pgn
# number of games: 16
# /Users/elliottmacneil/python/reti/output/conversions/78KPP20.pgn
# number of games: 23
# /Users/elliottmacneil/python/reti/output/conversions/69_76RPPr6.pgn
# number of games: 72
# /Users/elliottmacneil/python/reti/output/conversions/79_82KPp21.pgn
# number of games: 62
# /Users/elliottmacneil/python/reti/output/conversions/21_29Rvsp8.pgn
# number of games: 83
# /Users/elliottmacneil/python/reti/output/conversions/97RPb19.pgn
# number of games: 58
# /Users/elliottmacneil/python/reti/output/conversions/44_51ocBPPb28.pgn
# number of games: 64
# /Users/elliottmacneil/python/reti/output/conversions/8_9Rn12.pgn
# number of games: 98
# /Users/elliottmacneil/python/reti/output/conversions/42_43ocBPPb27.pgn
# number of games: 16
# /Users/elliottmacneil/python/reti/output/conversions/83_87KPPp24.pgn
# number of games: 50
# /Users/elliottmacneil/python/reti/output/conversions/56RPr26.pgn
# number of games: 93
# /Users/elliottmacneil/python/reti/output/conversions/13_15Np7.pgn
# number of games: 37
# /Users/elliottmacneil/python/reti/output/conversions/41ocBPPb9.pgn
# number of games: 9
# /Users/elliottmacneil/python/reti/output/conversions/11Np3.pgn
# number of games: 43
# /Users/elliottmacneil/python/reti/output/conversions/16_20Qp13.pgn
# number of games: 71
# /Users/elliottmacneil/python/reti/output/conversions/57_58RPr22.pgn
# number of games: 50
# /Users/elliottmacneil/python/reti/output/conversions/94_96RBr11.pgn
# number of games: 50
# /Users/elliottmacneil/python/reti/output/conversions/98RPb5.pgn
# number of games: 23
# /Users/elliottmacneil/python/reti/output/conversions/33_36BPb25.pgn
# number of games: 49
# /Users/elliottmacneil/python/reti/output/conversions/12Np14.pgn
# number of games: 65
# /Users/elliottmacneil/python/reti/output/conversions/93BN18.pgn
# number of games: 56
# /Users/elliottmacneil/python/reti/output/conversions/10Np16.pgn
# number of games: 43
# /Users/elliottmacneil/python/reti/output/conversions/55RPr15.pgn
# number of games: 50
# /Users/elliottmacneil/python/reti/output/conversions/6_7RB29.pgn
# number of games: 50
# /Users/elliottmacneil/python/reti/output/conversions/52_68RPr4.pgn
# number of games: 57
# /Users/elliottmacneil/python/reti/output/conversions/100Qrp23.pgn
# number of games: 15
# /Users/elliottmacneil/python/reti/output/conversions/1_5KP10.pgn
# number of games: 50
# /Users/elliottmacneil/python/reti/output/conversions/37_40BNP30.pgn
# number of games: 43

# %%
np.mean(df['white_elo'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [69], line 1
# ----> 1 np.mean(df['white_elo'])
#
# File <__array_function__ internals>:180, in mean(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3430, in mean(a, axis, dtype, out, keepdims, where)
#    3428         pass
#    3429     else:
# -> 3430         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3432 return _methods._mean(a, axis=axis, dtype=dtype,
#    3433                       out=out, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/generic.py:11119, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11101 @doc(
#   11102     _num_doc,
#   11103     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11117     **kwargs,
#   11118 ):
# > 11119     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/generic.py:10689, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10681 def mean(
#   10682     self,
#   10683     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10687     **kwargs,
#   10688 ) -> Series | float:
# > 10689     return self._stat_function(
#   10690         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10691     )
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/generic.py:10641, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10631     warnings.warn(
#   10632         "Using the level keyword in DataFrame and Series aggregations is "
#   10633         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   10636         stacklevel=find_stack_level(),
#   10637     )
#   10638     return self._agg_by_level(
#   10639         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10640     )
# > 10641 return self._reduce(
#   10642     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10643 )
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/series.py:4471, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4467     raise NotImplementedError(
#    4468         f"Series.{name} does not implement {kwd_name}."
#    4469     )
#    4470 with np.errstate(all="ignore"):
# -> 4471     return op(delegate, skipna=skipna, **kwds)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/nanops.py:410, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     407 if datetimelike and mask is None:
#     408     mask = isna(values)
# --> 410 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412 if datetimelike:
#     413     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/nanops.py:698, in nanmean(values, axis, skipna, mask)
#     695     dtype_count = dtype
#     697 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 698 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     700 if axis is not None and getattr(the_sum, "ndim", False):
#     701     count = cast(np.ndarray, count)
#
# File /opt/homebrew/lib/python3.10/site-packages/numpy/core/_methods.py:48, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
