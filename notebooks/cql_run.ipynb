# %% [markdown]
# # Build CQL (since this is a linux machine)

# %%
# %cd /content/drive/MyDrive/lichess_elite_db/elite_db_combined/reti/cqlsourcedist
# !make cql
# Out:
# /content/drive/MyDrive/lichess_elite_db/elite_db_combined/reti/cqlsourcedist
# make -C ./orig origstuff
# make[1]: Entering directory '/content/drive/MyDrive/lichess_elite_db/elite_db_combined/reti/cqlsourcedist/orig'
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o bytebuf.o -c bytebuf.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o date.o -c date.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o dstring.o -c dstring.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o filter.o -c filter.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o game.o -c game.cpp
# game.cpp: In member function ‘errorT Game::WriteMoveList(TextBuffer*, uint, moveT*, bool, bool)’:
# game.cpp:1644:18: warning: variable ‘newline’ set but not used [-Wunused-but-set-variable]
#      const char * newline = "\n";
#                   ^~~~~~~
# At global scope:
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o gfile.o -c gfile.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o index.o -c index.cpp
# index.cpp: In member function ‘errorT Index::Open(fileModeT, bool)’:
# index.cpp:966:12: warning: variable ‘modeStr’ set but not used [-Wunused-but-set-variable]
#      char * modeStr;
#             ^~~~~~~
# At global scope:
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o matsig.o -c matsig.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o mfile.o -c mfile.cpp
# mfile.cpp: In member function ‘errorT MFile::ReadLine(char*, uint)’:
# mfile.cpp:236:15: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#          fgets (str, (int) maxLength, Handle);
#          ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# At global scope:
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o misc.o -c misc.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o movelist.o -c movelist.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o myassert.o -c myassert.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o namebase.o -c namebase.cpp
# In file included from namebase.h:22:0,
#                  from namebase.cpp:17:
# strtree.h: In instantiation of ‘nodeT<C>* StrTree<C>::MakeSubTree(int, uint) [with C = nameDataT; uint = unsigned int]’:
# strtree.h:349:35:   required from ‘void StrTree<C>::MakeTree() [with C = nameDataT]’
# strtree.h:140:48:   required from ‘void StrTree<C>::Rebalance() [with C = nameDataT]’
# namebase.cpp:246:29:   required from here
# strtree.h:312:24: warning: variable ‘mid’ set but not used [-Wunused-but-set-variable]
#      int nLeft, nRight, mid;
#                         ^~~
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o pgnparse.o -c pgnparse.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o position.o -c position.cpp
# position.cpp: In member function ‘void Position::MakeSANString(simpleMoveT*, char*, sanFlagT)’:
# position.cpp:2168:24: warning: variable ‘r2’ set but not used [-Wunused-but-set-variable]
#              char r, f, r2, f2;
#                         ^~
# At global scope:
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o stored.o -c stored.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o stralloc.o -c stralloc.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o textbuf.o -c textbuf.cpp
# textbuf.cpp: In member function ‘void TextBuffer::SetBufferSize(uint)’:
# textbuf.cpp:86:18: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for(int i=0;i<length+128;++i) // added by stiller 2/26/2019 for reproducibility of bugs
#                  ~^~~~~~~~~~~
# At global scope:
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -I.. -o tree.o -c tree.cpp
# make[1]: Leaving directory '/content/drive/MyDrive/lichess_elite_db/elite_db_combined/reti/cqlsourcedist/orig'
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o abortnode.o -c abortnode.cpp
# In file included from node.h:10:0,
#                  from abortnode.h:2,
#                  from abortnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o absnode.o -c absnode.cpp
# In file included from node.h:10:0,
#                  from absnode.h:2,
#                  from absnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o andnode.o -c andnode.cpp
# In file included from node.h:10:0,
#                  from andnode.h:2,
#                  from andnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o arithmeticnode.o -c arithmeticnode.cpp
# In file included from node.h:10:0,
#                  from arithmeticnode.h:1,
#                  from arithmeticnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o assertnode.o -c assertnode.cpp
# In file included from node.h:10:0,
#                  from assertnode.h:2,
#                  from assertnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o assignment-parse.o -c assignment-parse.cpp
# In file included from node.h:10:0,
#                  from assignment-parse.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = Node]’:
# compoundnode.h:16:32:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SeqConstituent]’:
# seqconstituent.h:63:39:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o assignnode.o -c assignnode.cpp
# In file included from node.h:10:0,
#                  from assignnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o attack.o -c attack.cpp
# In file included from node.h:10:0,
#                  from attack.h:2,
#                  from attack.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o attacknode.o -c attacknode.cpp
# In file included from node.h:10:0,
#                  from attacknode.h:1,
#                  from attacknode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o betweennode.o -c betweennode.cpp
# In file included from node.h:10:0,
#                  from betweennode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o bracketrange.o -c bracketrange.cpp
# In file included from node.h:10:0,
#                  from bracketrange.h:2,
#                  from bracketrange.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o caseconvertnode.o -c caseconvertnode.cpp
# In file included from node.h:10:0,
#                  from caseconvertnode.h:2,
#                  from caseconvertnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o chesstypes.o -c chesstypes.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o childnode.o -c childnode.cpp
# In file included from node.h:10:0,
#                  from childnode.h:2,
#                  from childnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o clone.o -c clone.cpp
# In file included from node.h:10:0,
#                  from clone.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = Node]’:
# compoundnode.h:16:32:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SeqConstituent]’:
# seqconstituent.h:63:39:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o colortransform.o -c colortransform.cpp
# In file included from node.h:10:0,
#                  from colortransform.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o colortypenode.o -c colortypenode.cpp
# In file included from node.h:10:0,
#                  from colortypenode.h:2,
#                  from colortypenode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o colorvaluenode.o -c colorvaluenode.cpp
# In file included from node.h:10:0,
#                  from colorvaluenode.h:2,
#                  from colorvaluenode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o commententry.o -c commententry.cpp
# In file included from node.h:10:0,
#                  from commententry.cpp:2:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o commentnode.o -c commentnode.cpp
# In file included from node.h:10:0,
#                  from commentnode.h:3,
#                  from commentnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o commentstack.o -c commentstack.cpp
# commentstack.cpp: In member function ‘CommentEntry& CommentStack::at(int)’:
# commentstack.cpp:31:18: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    uassert(i>=0&&i<stack.size(),"CommentStack:at: bad i");
#                  ~^~~~~~~~~~~~~
# At global scope:
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o complementnode.o -c complementnode.cpp
# In file included from node.h:10:0,
#                  from complementnode.h:2,
#                  from complementnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o composetransform.o -c composetransform.cpp
# In file included from node.h:10:0,
#                  from composetransform.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o compoundnode.o -c compoundnode.cpp
# In file included from node.h:10:0,
#                  from compoundnode.h:2,
#                  from compoundnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = Node]’:
# compoundnode.h:16:32:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o computeorbit.o -c computeorbit.cpp
# In file included from node.h:10:0,
#                  from orbitnode.h:2,
#                  from computeorbit.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o concatenationnode.o -c concatenationnode.cpp
# In file included from node.h:10:0,
#                  from concatenationnode.h:2,
#                  from concatenationnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o consecutivemovesnode.o -c consecutivemovesnode.cpp
# consecutivemovesnode.cpp: In member function ‘std::vector<QMove*> ConsecutiveMovesNode::movepath(QPos*, QPos*)’:
# consecutivemovesnode.cpp:77:21: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    uassert(ret.size()==finishorig->getPly()-start->getPly(),"cmn movepath ply");
#            ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# consecutivemovesnode.cpp: In member function ‘std::vector<std::pair<QMove*, QMove*> > ConsecutiveMovesNode::compute(QPos*, QPos*)’:
# consecutivemovesnode.cpp:90:85: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    uassert(leftpath.front()->head==L&&leftpath.back()->tail==leftpos&&leftpath.size()==leftpos->getPly()-L->getPly(),"cmn compute bad leftpath");
#                                                                       ~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# consecutivemovesnode.cpp:91:89: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    uassert(rightpath.front()->head==L&&rightpath.back()->tail==rightpos&&rightpath.size()==rightpos->getPly()-L->getPly(),"cmn compute bad rightpath");
#                                                                          ~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# consecutivemovesnode.cpp:99:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    uassert(mylen<=leftints.size()&&mylen<=rightints.size()&&
#            ~~~~~^~~~~~~~~~~~~~~~~
# consecutivemovesnode.cpp:99:40: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    uassert(mylen<=leftints.size()&&mylen<=rightints.size()&&
#                                    ~~~~~^~~~~~~~~~~~~~~~~~
# consecutivemovesnode.cpp:101:14: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#     leftstarti<leftints.size()&&
#     ~~~~~~~~~~^~~~~~~~~~~~~~~~
# consecutivemovesnode.cpp:102:15: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#     rightstarti<rightints.size(),"cmn bad lcs return");
#     ~~~~~~~~~~~^~~~~~~~~~~~~~~~~
# consecutivemovesnode.cpp:103:29: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    uassert(mylen + leftstarti<=leftints.size(),"cmn leftintssize a");
#            ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~
# consecutivemovesnode.cpp:104:30: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    uassert(mylen + rightstarti<=rightints.size(),"cmn rightintssize a");
#            ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
# In file included from node.h:10:0,
#                  from consecutivemovesnode.h:2,
#                  from consecutivemovesnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# At global scope:
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o countsquaresnode.o -c countsquaresnode.cpp
# In file included from node.h:10:0,
#                  from countsquaresnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o cql.o -c cql.cpp
# In file included from node.h:10:0,
#                  from cql.cpp:5:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o cqleassert.o -c cqleassert.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o cqluassert.o -c cqluassert.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o cqlexit.o -c cqlexit.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o cqlglobals.o -c cqlglobals.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o cqlinitialize.o -c cqlinitialize.cpp
# In file included from node.h:10:0,
#                  from cqlinitialize.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o cqlnode.o -c cqlnode.cpp
# In file included from node.h:10:0,
#                  from cqlnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = Node]’:
# compoundnode.h:16:32:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SeqConstituent]’:
# seqconstituent.h:63:39:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o cqlnodematch.o -c cqlnodematch.cpp
# In file included from node.h:10:0,
#                  from cqlnodematch.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o cqlnode-parse.o -c cqlnode-parse.cpp
# In file included from node.h:10:0,
#                  from cqlnode-parse.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = Node]’:
# compoundnode.h:16:32:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SeqConstituent]’:
# seqconstituent.h:63:39:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o cqlthread.o -c cqlthread.cpp
# In file included from node.h:10:0,
#                  from cqlthread.h:1,
#                  from cqlthread.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = Node]’:
# compoundnode.h:16:32:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SeqConstituent]’:
# seqconstituent.h:63:39:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o currentfen.o -c currentfen.cpp
# In file included from node.h:10:0,
#                  from currentfen.h:2,
#                  from currentfen.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o currentnode.o -c currentnode.cpp
# In file included from node.h:10:0,
#                  from currentnode.h:2,
#                  from currentnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# ...
# In file included from node.h:10:0,
#                  from unionnode.h:2,
#                  from unionnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o util.o -c util.cpp
# util.cpp: In static member function ‘static std::__cxx11::string util::game_to_string(Game*)’:
# util.cpp:79:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    if(ret.size()>buffersize-5)
#       ~~~~~~~~~~^~~~~~~~~~~~~
# util.cpp: In static member function ‘static bool util::readPositiveInt(std::__cxx11::string*, int*)’:
# util.cpp:169:12: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(i=0;i<sourcep->size();++i){
#            ~^~~~~~~~~~~~~~~~
# util.cpp:176:17: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    uassert(i>0&&i<=sourcep->size(),"readPositiveInt internal");
#                 ~^~~~~~~~~~~~~~~~~
# util.cpp: In static member function ‘static bool util::readString(std::__cxx11::string*, std::__cxx11::string)’:
# util.cpp:188:13: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for (i=0;i<pattern.size();++i)
#             ~^~~~~~~~~~~~~~~
# util.cpp:189:10: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      if (i>=sourcep->size() ||
#          ~^~~~~~~~~~~~~~~~~
# util.cpp:191:12: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    uassert(i==pattern.size(),"readString pattern");
#            ~^~~~~~~~~~~~~~~~
# At global scope:
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o variable.o -c variable.cpp
# In file included from node.h:10:0,
#                  from variable.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o variable-parse.o -c variable-parse.cpp
# In file included from node.h:10:0,
#                  from variable-parse.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = Node]’:
# compoundnode.h:16:32:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SeqConstituent]’:
# seqconstituent.h:63:39:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o vectorconstituent.o -c vectorconstituent.cpp
# In file included from node.h:10:0,
#                  from sequencebase.h:2,
#                  from vectorconstituent.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SeqConstituent]’:
# seqconstituent.h:63:39:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o vectornode.o -c vectornode.cpp
# In file included from node.h:10:0,
#                  from vectornode.h:2,
#                  from vectornode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o version.o -c version.cpp
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o virtualmainlinenode.o -c virtualmainlinenode.cpp
# In file included from node.h:10:0,
#                  from virtualmainlinenode.h:2,
#                  from virtualmainlinenode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o whilenode.o -c whilenode.cpp
# In file included from node.h:10:0,
#                  from whilenode.h:2,
#                  from whilenode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o withpositionnode.o -c withpositionnode.cpp
# In file included from node.h:10:0,
#                  from withpositionnode.h:2,
#                  from withpositionnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o writefilenode.o -c writefilenode.cpp
# In file included from node.h:10:0,
#                  from writefilenode.h:4,
#                  from writefilenode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig -o yearnode.o -c yearnode.cpp
# In file included from node.h:10:0,
#                  from yearnode.cpp:1:
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = SetBase]’:
# node.h:380:38:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for(int i=0;i<v.size();++i){
# clonevec.h: In instantiation of ‘void clonevec(std::vector<T*>&) [with T = GameFilter]’:
# cqlnode.h:37:61:   required from here
# clonevec.h:3:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-unused-private-field’
# cc1plus: warning: unrecognized command line option ‘-Wno-deprecated-register’
# g++ -pthread -g -O -Wno-deprecated-register -Wno-unused-private-field -std=c++17 -Wall -Wno-write-strings -Wno-char-subscripts  -Wno-parentheses -fdiagnostics-show-option   -DASSERTIONS -I. -I./orig abortnode.o absnode.o andnode.o arithmeticnode.o assertnode.o assignment-parse.o assignnode.o attack.o attacknode.o betweennode.o bracketrange.o caseconvertnode.o chesstypes.o childnode.o clone.o colortransform.o colortypenode.o colorvaluenode.o commententry.o commentnode.o commentstack.o complementnode.o composetransform.o compoundnode.o computeorbit.o concatenationnode.o consecutivemovesnode.o countsquaresnode.o cql.o cqleassert.o cqluassert.o cqlexit.o cqlglobals.o cqlinitialize.o cqlnode.o cqlnodematch.o cqlnode-parse.o cqlthread.o currentfen.o currentnode.o currenttransformnode.o depthnode.o descendantnode.o dictionary.o dictionaryaccessnode.o dihedraltransform.o direction.o directionmatch.o directionparameter.o distancenode.o echonode.o elonode.o environment.o equalitynode.o extensionnode.o extremalnode.o fen.o filename.o findnode.o futurenode.o gamefilterwrapper.o gamenumbernode.o gamesortinfo.o gotonode.o groupnumbernode.o hascommentnode.o hhdbawardnode.o hhdbaward-parse.o hhdb-cql.o hhdbhascooknode.o hhdbkeyword.o hhdbkeyword-vars.o hhdb-options-parse.o hhdb-parse.o hhdbaward-sort.o holderconstituent.o ifnode.o isboundnode.o keywords.o lambdacallnode.o lambdamatch.o lambdavalue.o lambdavariable.o lcanode.o lexer.o linearize.o longestcommonsubstring.o loopnode.o makesquarenode.o markboardstatic.o match.o matchcomplexnode.o matchcountnode.o matchnode.o movebase.o move-parse.o movefuture.o movepast.o movelegalnode.o movenumbernode.o node.o node-parse.o nodetransform.o nonemptynode.o notnode.o notransformnode.o numbernode.o numericiteratornode.o numericvariable.o orbitelement.o orbitnode.o origChanges.o onnode.o optionalconstituent.o ornode.o parentnode.o pastnode.o pgnsource.o piecedesignator-lex.o pieceassignnode.o pieceidnode.o pieceidvariable.o pieceloc.o pieceloopnode.o pinnode.o piover4transform.o plynode.o plusconstituent.o positionindexnode.o positionvariable.o powernode.o print.o qgame.o qmarkboard.o qmove.o qpos.o qpos-visit.o range.o rangenode.o raynode.o readfilenode.o regexhistory.o relationalnode.o removecommentnode.o repeatconstituent.o repeatinprocessconstituent.o seqconstituent.o sequencebase.o sequencebase-comments.o sequencenest.o sequence-parse.o setbase.o shifttransform.o sortnode.o sortvalue.o sortvariable.o sqrtnode.o squarecoordinatenode.o squareloopnode.o squaremask.o squareparitynode.o squarevariable.o starconstituent.o stringasciinode.o stringconverter.o stringconverter-parse.o stringinnode.o stringiteratornode.o stringlengthnode.o stringliteralnode.o stringmatchnode.o stringtointnode.o stringvariable.o subsetnode.o substringnode.o substringassignmentnode.o tagbuiltinnode.o tagentry.o tagnode.o tagsection.o tagsetnode.o token.o tokens.o tomovenode.o tomovevaluenode.o toplevel.o toplevel-aux.o transform.o transformcompare.o transform_members.o transform-parse.o transformvariable.o unbindnode.o unionnode.o util.o variable.o variable-parse.o vectorconstituent.o vectornode.o version.o virtualmainlinenode.o whilenode.o withpositionnode.o writefilenode.o yearnode.o orig/bytebuf.o orig/date.o orig/dstring.o orig/filter.o orig/game.o orig/gfile.o orig/index.o orig/matsig.o orig/mfile.o orig/misc.o orig/movelist.o orig/myassert.o orig/namebase.o orig/pgnparse.o orig/position.o orig/stored.o orig/stralloc.o orig/textbuf.o orig/tree.o -o cql

# %% [markdown]
# # Download PGNs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/lichess_elite_db/elite_db_combined
# Out:
# /content/drive/MyDrive/lichess_elite_db/elite_db_combined

# %%
! pip3 install chess
import subprocess
import os
import shutil
import pandas as pd
import sys
sys.path.append('/content/drive/MyDrive/lichess_elite_db/elite_db_combined/reti/src/main')
from utilities import *
import chess
import chess.engine
import chess.pgn
import re
import itertools
# Out:
# Requirement already satisfied: chess in /opt/homebrew/lib/python3.10/site-packages (1.9.3)

# %% [markdown]
# # Run CQL6 scripts on the pgns

# %%
cql_bin_dir = '/Users/elliottmacneil/chess/cql6/cql'
cql_scripts_dir = '/Users/elliottmacneil/python/reti/src/silly/'
output_dir = '/Users/elliottmacneil/python/reti/output/'
iterated = False
db_dir = '/Users/elliottmacneil/chess/pgn/lichess_elite_db_all/lichess_elite_2022-06.pgn'

# %%
def run_cql_scripts(cql_scripts_dir,db,count):
    for file in os.listdir(cql_scripts_dir):
        print(file)
        file_dir = cql_scripts_dir+'/'+file
        file_noext = os.path.splitext(file)[0]
        dir_noext = os.path.join(output_dir,file_noext)
        pgn_file = dir_noext+str(count)+'.pgn'
        cql_command = cql_bin_dir+' -i '+db+' -o '+pgn_file+' -matchcount 1 100 '+file_dir
        try:
          subprocess.run(cql_command,shell=True)
        except:
          print('failed')
        count += 1
    return 0

# %%
if iterated:
    count = 0
    for filename in os.listdir(db_dir):
        if filename.endswith('.pgn'):
            print(filename)
            db = db_dir + '/' + filename
            run_cql_scripts(cql_scripts_dir,db,count)
            count += 1
else:
    run_cql_scripts(cql_scripts_dir,db_dir,count=1)
# Out:
# onlymoveep.cql
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# .........[10000]
# .........[20000]
# .........[30000]
# .........[40000]
# .........[50000]
# .........[60000]
# .........[70000]
# .........[80000]
# .........[90000]
# .........[100000]
# .........[110000]
# .........[120000]
# .........[130000]
# .........[140000]
# .........[150000]
# .........[160000]
# .........[170000]
# .........[180000]
# .........[190000]
# .........[200000]
# .........[210000]
# .........[220000]
# .........[230000]
# .........[240000]
# .........[250000]
# .........[260000]
# .........[270000]
# .........[280000]
# .........[290000]
# .........[300000]
# .........[310000]
# .........[320000]
# .........[330000]
# .....
# 12 matches of 335231 games in 22.2 seconds using 7 threads to /Users/elliottmacneil/python/reti/output/onlymoveep1.pgn
# onelymovemate.cql
# CQL version 6.1 (build 9.362) (c) Gady Costeff and Lewis Stiller
# .........[10000]
# .........[20000]
# .........[30000]
# .........[40000]
# .........[50000]
# .........[60000]
# .........[70000]
# .........[80000]
# .........[90000]
# .........[100000]
# .........[110000]
# .........[120000]
# .........[130000]
# .........[140000]
# .........[150000]
# .........[160000]
# .........[170000]
# .........[180000]
# .........[190000]
# .........[200000]
# .........[210000]
# .........[220000]
# .........[230000]
# .........[240000]
# .........[250000]
# .........[260000]
# .........[270000]
# .........[280000]
# .........[290000]
# .........[300000]
# .........[310000]
# .........[320000]
# .........[330000]
# .....
# 1 matches of 335231 games in 23.1 seconds using 7 threads to /Users/elliottmacneil/python/reti/output/onelymovemate2.pgn

# %%
import glob

def merge_pgns(pgn_dir):
  '''
  Given the directory with all the pgns in it, output a pgn with all the results in one file
  '''
  dir = pgn_dir+'/*.pgn'
  read_files = glob.glob(dir)
  with open("0all.pgn", "wb") as outfile:
    for f in read_files:
        with open(f, "rb") as infile:
            outfile.write(infile.read())
  return 0

# %%
# !cd /content/drive/MyDrive/lichess_elite_db/elite_db_combined/reti/output

cwd = os.getcwd()
cwd = cwd + '/output/'
print(cwd)
merge_pgns(cwd)
# Out:
# /content/drive/MyDrive/lichess_elite_db/elite_db_combined/reti/output/
# 0

# %%
# %cd /content/drive/MyDrive/lichess_elite_db/elite_db_combined/reti/output
# !find ./ -type f -name 1tripled-pawns9.pgn
# Out:
# /content/drive/MyDrive/lichess_elite_db/elite_db_combined/reti/output

# %% [markdown]
# # Process the PGN outputs from CQL6

# %%
def chop_game_after_cql():
  '''
  Given a pgn which has been processed by cql, output a pgn with games which 
  have only the first CQL comment present. Everything after it is removed.
  '''

  return 0

def play_through_games(pgn_dir):
  content = load_pgn(pgn_dir)
  games = game_length_array(content)
  num_games = len(games)
  pgn = open(pgn_dir)
  for game in range(num_games):
    selected_game = chess.pgn.read_game(pgn)
    board = selected_game.board()
    for move in selected_game.main_line():
      board.push(move)
    print(board)
  return 0

# %%
play_through_games('/content/drive/MyDrive/lichess_elite_db/elite_db_combined/lichess_elite_2020-06.pgn')
# Out:
# Streaming output truncated to the last 5000 lines.
# P . . . . . . .
# . . . . . . . P
# . . . . . . P .
# . . q B . . . K
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . K . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . p .
# . . . . Q . Q .
# . . . . k . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . r . . . k .
# . . . . . p p .
# p . . p . . . .
# . . . P p P b .
# . . q . B . . .
# . . . . . Q P .
# . . . . . . . P
# B . . . . R . K
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . .
# . . . . . . . b
# p . . . . B . P
# . . . . . p . .
# p . . . . P q K
# . . . k . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# r . . q . . . r
# p . . N k p . p
# . p . b p . p .
# . B n . . . B .
# . . . . . . . .
# Q . . . . . . .
# P . . . . P P P
# R . . . K . . R
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# r . . . . . r .
# p p . . q . . k
# . . . p . p . .
# . n p P p B . p
# . . . . . . . P
# . . P P . . . .
# P P . Q . . . K
# R . . . . . R .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# k b . . . . . .
# . . . . . . . .
# p . K . . . . R
# P b . . . . . .
# . . . B . . . .
# . . . . . p . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# r . . . . . . k
# p . Q . . . q P
# . . . . . p p .
# . . . . . . . .
# . p . . P . . .
# . . p . . . . .
# P P . . . P P .
# . . . . . . K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . r . . k .
# p p . . q p p p
# . . p . b . . .
# . . . . . . . .
# . . N . P . . .
# . . P Q . P . .
# . R . . . . P P
# . . . . . . . K
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . k .
# . . . . . . N .
# . . . . . . p .
# . . . . n p K .
# . . . . . . . P
# . . . . P . P .
# r . . . . P . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . r . . .
# . p . . . . . k
# . . . . . . . .
# p . p . . . . .
# . . . p . . . N
# . P . P . . K .
# P . . R . . P P
# . . . . . n . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . p . . . . k .
# p . . . . . . .
# . . . . p B . .
# . . p . Q . P b
# . . . . . . . P
# . P P . . q . .
# . . . . . K . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . B k . .
# . R . . p p . .
# . . . p . . p .
# . . . P . . P p
# . P . . . P . .
# . . . n . . . r
# . . . . . . . .
# . . . . R . K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . K . . . . . .
# . q . . . . . .
# . . k . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . B . . P . P
# k Q . . P K . .
# . . . . . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# q . . . . . k .
# . . Q . . p b p
# . . . . . . p .
# . . B R P . . .
# . . . . . P . .
# . P . . . . . .
# . P P . . . . P
# . K . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# r . . . r k . .
# . p . . . . . p
# . . p . . R . .
# p . . . p b . .
# P . . . . . . .
# . P . . . . P P
# . . P . . K B .
# . . . R . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . k . .
# . . p . . . . .
# . . . p . . . p
# . . . B . . . .
# . P . . . . . .
# P . . . . . q .
# . . . R . . . .
# . K . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . k .
# . . b . . . . .
# p . . . . . p .
# . p . K . . . p
# . . . . . . . .
# . P . . . . . P
# P . . . . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . . . . . . p .
# . . . . . . K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# r . . . . . . k
# . . . . . p p p
# . q r . p n . .
# . P . p . b . .
# P . . P . . . .
# . Q . . P . . .
# . . . . . P P P
# R . . . . R K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . k .
# . . . . . . . .
# . . . P . . . P
# . . p . . . r .
# . . . . . . . .
# . . . . . . . .
# . . . . . . K .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . .
# . . p . k . . .
# . . P n R . . .
# P . . . . . . r
# . . . . . . . .
# . . K . . . . .
# . . . . R . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . k .
# . R . . . . . p
# . . . . . p . .
# . . . p . P . .
# . p n P . K . .
# . . . . . N . P
# . r . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . Q . . . . . .
# . . . . . . . .
# . . . . k . . .
# . . . N . . p .
# . . . n . . R .
# . K . . . . . .
# . . . . . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . R . . r . .
# p . . P . . . p
# . . . . p k p .
# . B . b . p . .
# . . . . . . . .
# P . P . . . . .
# . . . . . . P P
# . . . . . . K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# r r . . . . . .
# p . . . . p P k
# . . n . . . . .
# q . . p . P . N
# . b . P p . Q P
# . . B . . . . .
# P P . . . . . .
# . K . R . . . R
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# r . . . . . . k
# p p . . . R . p
# . . n p Q . . B
# . . . p . . . .
# . . . b q . . .
# . . P . . . P .
# P P . . . . . P
# . . . . . . K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . p .
# . K . . . k . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . .
# K . k . . p . .
# P . . . . P p .
# . . . . . . P .
# . . . . . . . .
# . . . . . . P .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . q k . . .
# . . . . . Q . p
# . . . . B . p P
# p . . . . p . .
# . p . . . . . .
# . P . . P . . .
# P . . . . r . .
# . K . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# b . . . k b . .
# . . . n . p . .
# p . . p p . . p
# . . . . . . . r
# . . N . P . . .
# . . N . B . P .
# . P . . Q . . .
# R . . R . . K q
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . r . . . r
# k Q . . . p p p
# . . . q p . . .
# p R . . . . . P
# . N . . . . . .
# . . . . P . . .
# P P . . . . . .
# . K . . . . . R
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . .
# . . . . . . K .
# . . . . . . . .
# . . . . . . . .
# . . . . . . P k
# . . . . . . . P
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . b . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . K . .
# . . . . . . . .
# . . . . k B . p
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . r . . . r k .
# n . . b q p b .
# . . . . p . p .
# . p R . . . . .
# . P N p P N . p
# . . . P . . P .
# P . . . . P B P
# . . . . . R K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . R . . . k n .
# . . . . b . . .
# . . . . . p n .
# . . . . p . p p
# . . Q p P . . .
# r . . P . P P .
# . . . . N . K .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . R . . . .
# . . . . . p p k
# p . . . . . . .
# . p . . B . . .
# . . . . . . . .
# P P . . P P . n
# . . r . . . . P
# . . . . . . K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . p . . . . . k
# p . b . . . p P
# P . K . . . B .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . p
# . . . . . k . .
# . . . . . p p .
# . . . . . . . .
# . . r . . . P .
# . . . . . P K P
# . . . B R . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . n k . . b . r
# . B . . . R p p
# . . . . . . . .
# . . . . . . B .
# P . . p . . . .
# . . P . . P . .
# . . K . . P . P
# . . . . . . . r
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . K p .
# . . . . R . . .
# . . . . . k . .
# . . . . . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# r . . . . b r .
# . . . k . p . .
# p . . . p B . p
# . p . . P . . .
# . . p P . . . .
# . . . . q P . .
# . . . . . . . P
# R Q . . . K . R
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . B . . . . .
# . . . . . . . .
# P . . . p . . p
# . . . . k . . P
# . r . . . . P .
# . . . . . P K .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# R . . . . . . .
# P . . . . . b .
# . . p . . . . .
# . . . . p B . .
# . . . . P . . .
# . . . . . k p .
# r . . . . . . .
# . . . . . . K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . r . . k .
# . . p . . p p p
# p . . . . . . .
# . p . . . . . .
# . . . . . . . .
# . . P . P . . .
# P P K . . . . .
# R N B . . q . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . . . . . . . p
# . . . . . . . K
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . K n . . . . .
# P . . . . . . .
# . . . . . . . p
# . . . . k p . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . P P
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . r . . . . k .
# . . . . . . . p
# . K . . . . p .
# P . . . . p . .
# . . . . . . . .
# . R . . . P . .
# . . . . . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# r . . . . R . k
# . b . . P . r p
# p . . p . . p .
# . p q . p . . .
# . . . . P . . Q
# . B . . . . . .
# P P P . . . P P
# R . . . . . . K
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . k
# . . . . . . q P
# p . . . . p . .
# P p . . . . . .
# . . . . . b . .
# . . . . . P . K
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . n . . .
# P k . . . . . p
# n p . p p . p P
# . N p . . . P .
# . . P . P P . .
# . . N . . K . .
# . . . . . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . k .
# . . . . . . b .
# . . . . n . . p
# p . N . p . . P
# . . . . . p . .
# . . P . . P p .
# P . . K . . P .
# . . . . . . B R
# ...
# . . . . . Q . .
# . . . . . . . .
# . . p . . p k .
# . . . . p N p .
# . . . . . . p .
# . P . . . b . K
# P . . . . q . .
# . . . . . B . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . Q . r . . . .
# . . . . . . . .
# P . . . . . . .
# . . . P . . . .
# . . K . . . k P
# . . . . . . . .
# . q . . . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . R k . r
# p p p . . . . .
# . . n . . . Q .
# . . . . . . . q
# . . . . . . . .
# . . . . . . . .
# P P P . . P P .
# . . . . . R K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . k .
# . . . . . . p .
# p . . N . p . .
# . . . . p . . p
# R . . . P n P P
# . . . . . P . K
# . r . . . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . r . k .
# . p p . . p b .
# . . . . . . . .
# . . P q . . . .
# . . . P . . p .
# . . . . P N P .
# . . . . . P K .
# . . . Q . R . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . k .
# . p . . q p . p
# p . . p . . p .
# . . n Q . . . .
# . . P . . . . .
# . . . . . . N P
# . b B . . P P .
# . . . . . . K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . r
# . p . . . k . p
# p . . . . R . .
# . . . p . . . .
# . . . P . B . .
# . . P . . . P .
# P P . . K . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . R . .
# . p . p . . p k
# . . . P . . . .
# . P . . P K P p
# r . . . . P q P
# . . . Q . . . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# k . . r . . . .
# . p . . . . p .
# . . . . . . . p
# Q . . . . . . .
# . P . . . . P .
# . . . . . . . P
# P . . . . K P .
# . r . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# r . . . . b k .
# . b p . . p p .
# . . . . . . . p
# p . . . . . . .
# P p . . r . . .
# . . P q N . . P
# . P . B . P P .
# R . Q . . . K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . k . . . . .
# . p . . p . . .
# . b . p . . . .
# p . . . . . P .
# P . b . . . . .
# . . P . . . . .
# . K . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . k .
# p . p . . . . .
# . p . p . . . .
# . P . . p . p .
# P . . . . . . p
# . . . . . . . .
# . . . . . . . .
# . . . . . . K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . .
# . . . . . . p .
# . . . . . . P .
# P . . . . . P .
# . P . K . . . .
# . . P . . k . b
# . . . . q . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . Q . .
# . . p . . . . k
# . . . . . . p p
# . P . . P . b .
# . . . . . . . .
# P . . . . . B .
# . . . . q . K .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# R . . . . . . .
# . . . . . . p k
# . . . . . p . .
# . . . . . K . .
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# . . . R . k . .
# p . . . R . . r
# . p . . . . . .
# . . . p P . . p
# . P . . . . r B
# . . . K . . . .
# P . . . . . . b
# . . . . . . . .
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'accept', 'accept_subgame', 'add_line', 'add_main_variation', 'add_variation', 'board', 'board_cached', 'comment', 'demote', 'end', 'errors', 'from_board', 'has_variation', 'headers', 'is_end', 'is_main_line', 'is_main_variation', 'main_line', 'move', 'nags', 'parent', 'promote', 'promote_to_main', 'remove_variation', 'root', 'san', 'setup', 'starting_comment', 'starts_variation', 'uci', 'variation', 'variations', 'without_tag_roster']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-893696c52cae> in <module>
# ----> 1 play_through_games('/content/drive/MyDrive/lichess_elite_db/elite_db_combined/lichess_elite_2020-06.pgn')
#
# <ipython-input-37-4411a1f18f93> in play_through_games(pgn_dir)
#       9     print(dir(selected_game))
#      10     for move in selected_game.main_line():
# ---> 11       board.push(move)
#      12     print(board)
#      13   return 0
#
# /usr/local/lib/python3.7/dist-packages/chess/__init__.py in push(self, move)
#    1841         return bool(self.attacks_mask(move.from_square) & to_mask)
#    1842
# -> 1843     def is_legal(self, move: Move) -> bool:
#    1844         return not self.is_variant_end() and self.is_pseudo_legal(move) and not self.is_into_check(move)
#    1845
#
# /usr/local/lib/python3.7/dist-packages/chess/__init__.py in __init__(self, board)
#    1250                 piece = self.piece_at(square_index)
#    1251
# -> 1252                 if piece:
#    1253                     builder.append(piece.unicode_symbol(invert_color=invert_color))
#    1254                 else:
#
# KeyboardInterrupt:

# %%
import re

# %% [markdown]
# # Produce cql files looking for a given material imbalance

# %%
def partition_pieces(num_white_pieces=5,num_black_pieces=5,diff=0):
  option = []
  piece_values = [9,5,3,1]
  white = list(itertools.combinations_with_replacement('9531',num_white_pieces))
  black = list(itertools.combinations_with_replacement('9531',num_black_pieces))

  white = [[int(x[i]) for i in range(len(x))] for x in white]
  black = [[int(x[i]) for i in range(len(x))] for x in black]

  white_final = []
  black_final = []
  for setup in white:
    if (setup.count(9) <= 1) and (setup.count(5) <= 2) and (setup.count(3) <= 4):
      white_final.append(setup)
  for setup in black:
    if (setup.count(9) <= 1) and (setup.count(5) <= 2) and (setup.count(3) <= 4):
      black_final.append(setup)

  for idx_w in range(len(white_final)):
    for idx_b in range(len(black_final)):
      if abs(sum(white_final[idx_w]) - sum(black_final[idx_b])) == diff:
        option.append([white_final[idx_w],black_final[idx_b]])
  return option

def values_to_pieces(partition):
  for opt_idx, option in enumerate(partition):
    for set_idx, setup in enumerate(option):
      for pc_idx, piece in enumerate(setup):
        if piece == 9:
          partition[opt_idx][set_idx][pc_idx] = 'Q'
          if set_idx == 1:
            partition[opt_idx][set_idx][pc_idx] = partition[opt_idx][set_idx][pc_idx].lower()
        elif piece == 5:
          partition[opt_idx][set_idx][pc_idx] = 'R'
          if set_idx == 1:
            partition[opt_idx][set_idx][pc_idx] = partition[opt_idx][set_idx][pc_idx].lower()
        elif piece == 3:
          partition[opt_idx][set_idx][pc_idx] = '[BN]'
          if set_idx == 1:
            partition[opt_idx][set_idx][pc_idx] = partition[opt_idx][set_idx][pc_idx].lower()
        elif piece == 1:
          partition[opt_idx][set_idx][pc_idx] = 'P'
          if set_idx == 1:
            partition[opt_idx][set_idx][pc_idx] = partition[opt_idx][set_idx][pc_idx].lower()
  return partition

# %%
################################################################################
####################### TEST ###################################################

# ASSERT SYMMETRIC
for a in range(1,5):
  for b in range(1,5):
    for diff in range(5):
      assert len(partition_pieces(a,b,diff)) == len(partition_pieces(b,a,diff))

# %%
part = partition_pieces(5,2,1)
values_to_pieces(part)
# Out:
# [[['Q', '[BN]', 'P', 'P', 'P'], ['q', 'r']],
#  [['Q', 'P', 'P', 'P', 'P'], ['q', 'r']],
#  [['Q', 'P', 'P', 'P', 'P'], ['q', '[bn]']],
#  [['R', 'R', '[BN]', 'P', 'P'], ['q', 'r']],
#  [['R', 'R', 'P', 'P', 'P'], ['q', 'r']],
#  [['R', 'R', 'P', 'P', 'P'], ['q', '[bn]']],
#  [['R', '[BN]', '[BN]', '[BN]', 'P'], ['q', 'r']],
#  [['R', '[BN]', '[BN]', 'P', 'P'], ['q', 'r']],
#  [['R', '[BN]', '[BN]', 'P', 'P'], ['q', '[bn]']],
#  [['R', '[BN]', 'P', 'P', 'P'], ['q', '[bn]']],
#  [['R', '[BN]', 'P', 'P', 'P'], ['q', 'p']],
#  [['R', '[BN]', 'P', 'P', 'P'], ['r', 'r']],
#  [['R', 'P', 'P', 'P', 'P'], ['q', 'p']],
#  [['R', 'P', 'P', 'P', 'P'], ['r', 'r']],
#  [['R', 'P', 'P', 'P', 'P'], ['r', '[bn]']],
#  [['[BN]', '[BN]', '[BN]', '[BN]', 'P'], ['q', 'r']],
#  [['[BN]', '[BN]', '[BN]', '[BN]', 'P'], ['q', '[bn]']],
#  [['[BN]', '[BN]', '[BN]', 'P', 'P'], ['q', '[bn]']],
#  [['[BN]', '[BN]', '[BN]', 'P', 'P'], ['q', 'p']],
#  [['[BN]', '[BN]', '[BN]', 'P', 'P'], ['r', 'r']],
#  [['[BN]', '[BN]', 'P', 'P', 'P'], ['q', 'p']],
#  [['[BN]', '[BN]', 'P', 'P', 'P'], ['r', 'r']],
#  [['[BN]', '[BN]', 'P', 'P', 'P'], ['r', '[bn]']],
#  [['[BN]', 'P', 'P', 'P', 'P'], ['r', '[bn]']],
#  [['[BN]', 'P', 'P', 'P', 'P'], ['r', 'p']],
#  [['[BN]', 'P', 'P', 'P', 'P'], ['[bn]', '[bn]']],
#  [['P', 'P', 'P', 'P', 'P'], ['r', 'p']],
#  [['P', 'P', 'P', 'P', 'P'], ['[bn]', '[bn]']],
#  [['P', 'P', 'P', 'P', 'P'], ['[bn]', 'p']]]

# %%
# !rm -rf output
# !mkdir output
# %cd /content/drive/MyDrive/lichess_elite_db/elite_db_combined/reti/output/output
# Out:
# /content/drive/MyDrive/lichess_elite_db/elite_db_combined/reti/output/output

# %%
def write_cql_files(white_pieces,black_pieces,value_diff):
  part = partition_pieces(white_pieces,black_pieces,value_diff)
  pieces = values_to_pieces(part)
  # [BN] seems to mean B or N.
  piece_key = ['Q','R','[BN]','P','q','r','[bn]','p']
  for piece_setup in pieces:
    piece_counts = []
    for idx in range(2):
      for key in piece_key:
        piece_counts.append(piece_setup[idx].count(key))
    with open('{}.cql'.format(''.join([''.join(x) for x in piece_setup])), 'a') as f:
      f.write('cql()\n')
      f.write('[Aa]={}\n'.format(white_pieces+black_pieces+2))
      for idx, key in enumerate(piece_key):
        f.write('{} == {}\n'.format(key,piece_counts[idx]))
  return 0

# %%
write_cql_files(4,2,2)
# !ls
# Out:
# '[BN][BN][bn][bn].cql'	   PPPPpp.cql		    'R[BN]PPr[bn].cql'
# '[BN][BN][BN][BN]qp.cql'   PPPPrp.cql		    'R[BN]r[bn].cql'
# '[BN][BN][BN][BN]qr.cql'  'Q[BN][BN]Pqr.cql'	    'RP[bn][bn].cql'
# '[BN][BN][BN][BN]rr.cql'  'Q[BN]PPq[bn].cql'	    'RPPP[bn][bn].cql'
# '[BN][BN][BN]Pq[bn].cql'  'Q[BN]q[bn].cql'	     RPPPqp.cql
# '[BN][BN][BN]Pr[bn].cql'   QPPPqp.cql		     RPPPrp.cql
# '[BN][BN]PP[bn][bn].cql'   QPPPqr.cql		     RPPPrr.cql
# '[BN][BN]PPqp.cql'	   QPPPrr.cql		     RPrp.cql
# '[BN][BN]PPrp.cql'	   QPqp.cql		    'RR[BN][BN]qr.cql'
# '[BN][BN]PPrr.cql'	   QPrr.cql		    'RR[BN]Pq[bn].cql'
# '[BN][BN]rp.cql'	   QRPPqr.cql		     RRPPqp.cql
# '[BN]P[bn]p.cql'	   QRqr.cql		     RRPPqr.cql
# '[BN]PPP[bn]p.cql'	  'R[BN][BN][BN]q[bn].cql'   RRPPrr.cql
# '[BN]PPPr[bn].cql'	  'R[BN][BN]Pqp.cql'	     RRqp.cql
#  output			  'R[BN][BN]Pqr.cql'	     RRrr.cql
# 'PPPP[bn][bn].cql'	  'R[BN][BN]Prr.cql'
#  PPpp.cql		  'R[BN]PPq[bn].cql'
